# %% [markdown]
# # 🤖 R3D Bot — Google Colab Setup
# شغّل الخلايا بالترتيب من الأعلى للأسفل

# %%
# ── الخطوة 1: تثبيت Redis و FFmpeg ──
# !apt-get install -y redis-server ffmpeg > /dev/null 2>&1
# !redis-server --daemonize yes
import time; time.sleep(1)
# !redis-cli ping

# %%
# ── الخطوة 2: رفع ملف البوت ──
from google.colab import files
uploaded = files.upload()  # ارفع bot_project_v5_FINAL_EDITED.zip

# %%
# ── الخطوة 3: فك الضغط ──
# !unzip -q bot_project_v5_FINAL_EDITED.zip
# %cd bot_project
# !ls

# %%
# ── الخطوة 4: تثبيت المكتبات ──
# !pip install -q -r r3d.txt

# %%
# ── الخطوة 5: إعداد بيانات البوت ──
# ✏️ املأ البيانات هنا
BOT_TOKEN    = ""   # من @BotFather
OWNER_ID     = ""   # من @userinfobot
BOT_USERNAME = ""   # اسم البوت بدون @
API_ID       = ""   # من my.telegram.org
API_HASH     = ""   # من my.telegram.org

env = f"""BOT_TOKEN={BOT_TOKEN}
OWNER_ID={OWNER_ID}
BOT_USERNAME={BOT_USERNAME}
API_ID={API_ID}
API_HASH={API_HASH}
"""
with open(".env", "w") as f:
    f.write(env)
print("✅ ملف .env تم إنشاؤه")

# %%
# ── الخطوة 6: تشغيل البوت ──
# !python3 main.py
